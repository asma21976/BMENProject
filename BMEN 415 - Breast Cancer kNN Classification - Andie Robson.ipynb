# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("breast-cancer.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
Y=['diagnosis']
X=list(set(list(data.columns))-set(Y))
data[X]=data[X]/data[X].max()
data.describe().transpose()
# Out:
#                          count      mean       std       min       25%  \
# id                       569.0  0.033327  0.137186  0.000010  0.000954
# radius_mean              569.0  0.502572  0.125366  0.248346  0.416222
# texture_mean             569.0  0.491081  0.109497  0.247200  0.411660
# perimeter_mean           569.0  0.487899  0.128907  0.232308  0.398780
# area_mean                569.0  0.261851  0.140709  0.057377  0.168053
# smoothness_mean          569.0  0.589720  0.086072  0.322093  0.528580
# compactness_mean         569.0  0.302087  0.152903  0.056109  0.187956
# concavity_mean           569.0  0.208058  0.186785  0.000000  0.069260
# concave points_mean      569.0  0.243137  0.192857  0.000000  0.100944
# symmetry_mean            569.0  0.595927  0.090179  0.348684  0.532566
# fractal_dimension_mean   569.0  0.644475  0.072459  0.512726  0.592159
# radius_se                569.0  0.141028  0.096524  0.038810  0.080891
# texture_se               569.0  0.249100  0.112927  0.073736  0.170706
# perimeter_se             569.0  0.130394  0.091986  0.034440  0.073066
# area_se                  569.0  0.074395  0.083901  0.012545  0.032921
# smoothness_se            569.0  0.226180  0.096451  0.055027  0.166046
# compactness_se           569.0  0.188169  0.132261  0.016632  0.096603
# concavity_se             569.0  0.080540  0.076227  0.000000  0.038106
# concave points_se        569.0  0.223454  0.116884  0.000000  0.144686
# symmetry_se              569.0  0.260194  0.104704  0.099835  0.192020
# fractal_dimension_se     569.0  0.127175  0.088675  0.029987  0.075335
# radius_worst             569.0  0.451420  0.134108  0.220033  0.360988
# texture_worst            569.0  0.518313  0.124067  0.242632  0.425515
# perimeter_worst          569.0  0.426995  0.133768  0.200677  0.334833
# area_worst               569.0  0.207001  0.133840  0.043535  0.121133
# smoothness_worst         569.0  0.594648  0.102572  0.319721  0.523810
# compactness_worst        569.0  0.240326  0.148711  0.025794  0.139130
# concavity_worst          569.0  0.217403  0.166633  0.000000  0.091454
# concave points_worst     569.0  0.393836  0.225884  0.000000  0.223127
# symmetry_worst           569.0  0.436992  0.093202  0.235764  0.377222
# fractal_dimension_worst  569.0  0.404558  0.087042  0.265253  0.344386
#
#                               50%       75%  max
# id                       0.000994  0.009671  1.0
# radius_mean              0.475631  0.561366  1.0
# texture_mean             0.479633  0.554990  1.0
# perimeter_mean           0.457507  0.552255  1.0
# area_mean                0.220352  0.312955  1.0
# smoothness_mean          0.586720  0.644431  1.0
# compactness_mean         0.268182  0.377533  1.0
# concavity_mean           0.144189  0.306232  1.0
# concave points_mean      0.166501  0.367793  1.0
# symmetry_mean            0.589474  0.643750  1.0
# fractal_dimension_mean   0.631568  0.678571  1.0
# radius_se                0.112844  0.166690  1.0
# texture_se               0.226817  0.301740  1.0
# perimeter_se             0.104049  0.152730  1.0
# area_se                  0.045242  0.083346  1.0
# smoothness_se            0.204947  0.261677  1.0
# compactness_se           0.151034  0.239660  1.0
# concavity_se             0.065379  0.106187  1.0
# concave points_se        0.207047  0.278651  1.0
# symmetry_se              0.237239  0.297403  1.0
# fractal_dimension_se     0.106803  0.152748  1.0
# radius_worst             0.415372  0.521365  1.0
# texture_worst            0.512919  0.599919  1.0
# perimeter_worst          0.388774  0.499204  1.0
# area_worst               0.161378  0.254819  1.0
# smoothness_worst         0.589847  0.655885  1.0
# compactness_worst        0.200284  0.320510  1.0
# concavity_worst          0.181070  0.305831  1.0
# concave points_worst     0.343402  0.554639  1.0
# symmetry_worst           0.425128  0.478909  1.0
# fractal_dimension_worst  0.385735  0.443759  1.0

# %%
#splitting dataset into training and testing dataset
from sklearn.model_selection import train_test_split
X=data[X].values
Y=data[Y].values

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)#test size is 20% of the data, remaining 80 is training
print(X_train.shape, X_test.shape)
# Out:
# (455, 31) (114, 31)

# %%
from sklearn.neighbors import KNeighborsClassifier  
clf = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 ) #uses 5 nearest neigbors, minkowski decides the distance between the points
                                                                    # p=2 uses euclidean_distance (l2) 
clf.fit(X_train, np.ravel(Y_train))
# Out:
# KNeighborsClassifier()

# %%
Y_predict_train=clf.predict(X_train)
Y_predict_test=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.92      0.99      0.95        71
#            M       0.97      0.86      0.91        43
#
#     accuracy                           0.94       114
#    macro avg       0.95      0.92      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
from sklearn.metrics import confusion_matrix
cf=confusion_matrix(Y_test, Y_predict_test)

import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.heatmap(cf, annot=True, cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
